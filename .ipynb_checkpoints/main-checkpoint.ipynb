# %%
import io, json

vacancy_search_text = "golang middle"

def load_json_from_file(path):
    with io.open(path, encoding='utf-8', mode='r') as  json_file:
        return json.load(json_file)

raw_vacancy_data = load_json_from_file("json/"+vacancy_search_text+".json")
print(len(raw_vacancy_data))
# Out:
# 286

# %%
import datetime

def prepare_vacancy_data(vacancy_data):
    new_vacancy_data = []
    for vacancy in vacancy_data:
        new_vacancy = {}        
        new_vacancy["key_skills"] = ', '.join(list(vacancy["key_skills"] or []))
        #new_vacancy["key_skills"] = list(vacancy["key_skills"] or [])
        #new_vacancy["key_skills"] = pd.Series(data=list(vacancy["key_skills"] or []))
        new_vacancy["name"] = vacancy["name"]
        new_vacancy["id"] = vacancy["id"]        
        new_vacancy["description"] = vacancy["description"]
        new_vacancy["salary"] = vacancy["salary"]       
        new_vacancy["creation_time"] = vacancy["creation_time"]
        if "name" in vacancy["employer"]:
            new_vacancy["employer"] = vacancy["employer"]["name"]
        if "visible_name" in vacancy["employer"]:
            new_vacancy["employer"] = vacancy["employer"]["visible_name"]        
        
        if "schedule" in vacancy:
            if type(vacancy["schedule"]) == str:            
                new_vacancy["schedule"] = vacancy["schedule"]  
            if type(vacancy["schedule"]) == dict:            
                new_vacancy["schedule"] = vacancy["schedule"]["id"]   
            
        new_vacancy["accept_temporary"] = vacancy["accept_temporary"]       
        new_vacancy_data.append(new_vacancy)
    return new_vacancy_data

vacancys_data = prepare_vacancy_data(raw_vacancy_data)

# %%
import pandas as pd

df = pd.DataFrame(columns= list(vacancys_data[0].keys()))

ind = 0
for data in vacancys_data:     
    if (len(df.columns)==len(data)):
        df.loc[ind] = data
        ind+=1

df.to_csv(vacancy_search_text+".csv", encoding="utf8" )

df = pd.DataFrame()
df=pd.read_csv(vacancy_search_text+".csv", encoding="utf8" )

# %%
import math
from currency_converter import CurrencyConverter
c = CurrencyConverter()
from datetime import date # datetime works too

import re 

def process_salary_value (salary_structure):
    salary = salary_structure
    salary_value = False

    if ("from" in salary) and ("to" in salary):
        salary_value = ((salary["from"] or 0) + (salary["to"] or 0))/2
    else:
        if "from" in salary:
            salary_value = salary["from"]
        if "to" in salary:
            salary_value = salary["to"]    
    return salary_value

for vacancy in vacancys_data:
    if type(vacancy["salary"]) == dict:
        salary = vacancy["salary"]        
        salary_value = process_salary_value (salary)
                
        if salary_value and ("currency" in salary):
            if not(re.search(r'RUR', salary["currency"])):
                try:
                    salary_value = math.floor(c.convert(salary_value, salary["currency"], 'RUB'))
                    df.at[vacancys_data.index(vacancy),"salary"] = salary_value
                    #print(salary_value,"from", salary["currency"])                       
                except Exception as err:
                    #print("Problems with currency "+salary["currency"], err)
                    pass
            else:
                df.at[vacancys_data.index(vacancy),"salary"] = salary_value

# %%
import pandas as pd

pd.set_option("display.max_rows",None)
display(df)
# Out:
#      Unnamed: 0                                         key_skills  \
# 0             0                     Golang, gRPC, Linux, Go, Redis
# 1             1  Английский — B2 — Средне-продвинутый, Русский ...
# 2             2     ООП, PostgreSQL, SQL, Английский язык, MongoDB
# 3             3    PostgreSQL, Docker, REST, Kafka, Docker-compose
# 4             4                Git, PostgreSQL, Golang, Docker, Go
# 5             5  Golang, Средства криптографической защиты инфо...
# 6             6               Git, Go, ClickHouse, Linux, XML, Web
# 7             7  Golang, Kafka, Git, RabbitMQ, MongoDB, NoSQL, ...
# 8             8  JavaScript, TypeScript, React.js, Разработка н...
# 9             9                                             Golang
# 10           10  Golang, PostgreSQL, PHP, ClickHouse, Redis, GR...
# 11           11  Git, Python, PostgreSQL, ООП, Flask, Golang, A...
# 12           12                                             Golang
# 13           13              Golang, Git, PostgreSQL, Redis, Kafka
# 14           14  PostgreSQL, Git, Linux, Английский язык, Redis...
# 15           15  Golang, Git, Docker, Kubernetes, Английский яз...
# 16           16  Golang, Git, PostgreSQL, Redis, Elasticsearch,...
# 17           17                             СУБД, PostgreSQL, Bash
# 18           18                                                NaN
# 19           19                                             Golang
# 20           20                Golang, SQL, Docker, Kubernetes, Go
# 21           21                                 PostgreSQL, Golang
# 22           22                                                NaN
# 23           23  Git, ООП, Golang, Работа с базами данных, GitH...
# 24           24  golang, SQL, PostgreSQL, Redis, docker, Rabbit...
# 25           25                      Go, MySQL, Clickhouse, Golang
# 26           26                                                NaN
# 27           27  Английский — B1 — Средний, Git, Python, Redis,...
# 28           28  Golang, PostgreSQL, CockroachDB, MongoDB, Kafk...
# 29           29  Python, Django Framework, PostgreSQL, Linux, S...
# 30           30  Golang, PostgreSQL, Git, SQL, ООП, Docker, Выс...
# 31           31  Английский — B2 — Средне-продвинутый, Английск...
# 32           32  MySQL, PostgreSQL, SQL, HTML, HTTP API, API, G...
# 33           33  Английский — B1 — Средний, Linux, Python, Git,...
# 34           34                                                NaN
# 35           35  Golang, Git, MongoDB, PostgreSQL, Linux, Kuber...
# 36           36            Обучение и развитие, PostgreSQL, Golang
# 37           37           PostgreSQL, SQL, RabbitMQ, Golang, Redis
# 38           38                                 PostgreSQL, Golang
# 39           39  MySQL, PostgreSQL, SQL, HTML, HTTP API, API, G...
# 40           40  Английский — B2 — Средне-продвинутый, Golang, ...
# 41           41  Английский — A1 — Начальный, Golang, Git, MySQ...
# 42           42  MySQL, PostgreSQL, SQL, HTML, HTTP API, API, G...
# 43           43  Английский — B2 — Средне-продвинутый, Английск...
# 44           44  MongoDB, Golang, Node.js, Go, Docker, JavaScri...
# 45           45              Golang, RabbitMQ, Git, Python, Docker
# 46           46  Английский — B2 — Средне-продвинутый, Английск...
# 47           47  Английский — A1 — Начальный, ООП, Symfony, PHP...
# 48           48                                                NaN
# 49           49         golang, go, Linux, Docker, k8s, kubernetes
# 50           50  Linux, C++, С++ boost, Алгоритмы и структуры д...
# 51           51                                                NaN
# 52           52  MySQL, PHP, PostgreSQL, ООП, Docker, Symfony, ...
# 53           53                                 PostgreSQL, Golang
# 54           54              Git, ООП, Docker, golang, C++, Python
# 55           55  Английский — B1 — Средний, Python, PostgreSQL,...
# 56           56    Английский — A1 — Начальный, Golang, REST, gRPC
# 57           57            PHP, Git, MySQL, Laravel, Elasticsearch
# 58           58  Linux, C++, С++ boost, Алгоритмы и структуры д...
# 59           59  Golang, Linux, SQL, REST, Go, PostgreSQL, Git,...
# 60           60  Linux, PostgreSQL, TCP/IP, Unit Testing, СУБД,...
# 61           61  Blockchain, Rust, DeFi, NEAR Protocol, DEX, Or...
# 62           62  golang, SQL, PostgreSQL, Redis, docker, Rabbit...
# 63           63                 Python, Linux, K8S, Golang, Docker
# 64           64                                                NaN
# 65           65  Английский — B1 — Средний, Git, Linux, Английс...
# 66           66                                     Python, Golang
# 67           67                                   SQL, Git, Golang
# 68           68  Docker, PostgreSQL, RabbitMQ, Git, PHP, MySQL,...
# 69           69                   PHP, Symfony, PostgreSQL, Docker
# 70           70  Golang, Английский язык, XML, Go, Умение работ...
# 71           71                   Python, Terraform, Gitlab, CI/CD
# 72           72  MongoDB, Git, Docker, ООП, SQL, Node.js, NoSQL...
# 73           73                         C/C++, Python, PHP, Golang
# 74           74  SQL, Postrgres SQL, backend, PHP, Laravel, php...
# 75           75  PostgreSQL, NestJS, Typescript, JavaScript, Ba...
# 76           76                 Git, Golang, PostgreSQL, gRPC, SQL
# 77           77  Английский — A1 — Начальный, JavaScript, Node....
# 78           78  JavaScript, TypeScript, Node.js, React, AngularJS
# 79           79             SQL, GO, NET Core C#, С#, Linux, NoSQL
# 80           80  JavaScript, TypeScript, Golang, PHP, NestJS, W...
# 81           81  MySQL, PostgreSQL, SQL, HTML, HTTP API, API, G...
# 82           82  Python, Django Framework, Linux, Docker, Git, ...
# 83           83                       Golang, Linux, SQL, REST API
# 84           84                                                NaN
# 85           85            PHP, Git, MySQL, Laravel, Elasticsearch
# 86           86  Git, Golang, MongoDB, ООП, Node.js, SQL, MySQL...
# 87           87  Английский — B2 — Средне-продвинутый, Ruby On ...
# 88           88         MySQL, MongoDB, PostgreSQL, Symfony, Scrum
# 89           89                                                NaN
# 90           90    Git, Scrum, Golang, Backend, PostgreSQL, Python
# 91           91  Backend, Middle, Kubernetes, Python, Linux, Go...
# 92           92                            Go, Development, golang
# 93           93  Английский — B2 — Средне-продвинутый, JavaScri...
# 94           94  PHP, MySQL, ООП, Redis, PostgreSQL, Symfony, L...
# 95           95  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 96           96  веб-разработка, gоlang, PostgreSQL, docker, re...
# 97           97  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 98           98  Поисковые системы, Docker, CI/CD, Golang, Сист...
# 99           99  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 100         100   Golang, PostgreSQL, REST, Git, GRPC, Docker, SQL
# 101         101  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 102         102  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 103         103  Go, FinTech, golang, backend, Гибкий график на...
# 104         104  Удаленная работа, Go, FinTech, golang, backend...
# 105         105     gRPC, Golang, Английский язык, Redis, RabbitMQ
# 106         106  Разработка ПО, Golang, Серверное программирова...
# 107         107  Golang, PostgreSQL, SQL, RabbitMQ, Elasticsear...
# 108         108  Английский — B2 — Средне-продвинутый, AWS, Doc...
# 109         109                                        Python, SQL
# 110         110  Git, PostgreSQL, ООП, Linux, Финансовый контро...
# 111         111             Git, Английский язык, Go, Golang, Jira
# 112         112             Python, MySQL, SQL, Linux, Git, Golang
# 113         113   MySQL, PHP, phpMyAdmin, Symfony, Docker, MongoDB
# 114         114  Git, Golang, Docker, JavaScript, MySQL, SQL, A...
# 115         115   MySQL, PHP, phpMyAdmin, Symfony, Docker, MongoDB
# 116         116   MySQL, PHP, phpMyAdmin, Symfony, Docker, MongoDB
# 117         117  Git, Docker, Linux, PostgreSQL, Английский язы...
# 118         118  Английский — A1 — Начальный, Golang, Поисковые...
# 119         119  Linux, Golang, Git, Организация мероприятий, g...
# 120         120                                                NaN
# 121         121                    Golang, JavaScript, C++, TCP/IP
# 122         122  Английский — B1 — Средний, Git, PostgreSQL, Li...
# 123         123  Английский — B1 — Средний, Английский язык, Pr...
# 124         124  Golang, Git, Linux, PostgreSQL, Docker, ClickH...
# 125         125  Spark, Hive, Big Data, Microsoft Access, Удале...
# 126         126                Git, Golang, Linux, ООП, PostgreSQL
# 127         127                                 MySQL, Golang, PHP
# 128         128                                                NaN
# 129         129             MySQL, PHP, Docker, Kubernetes, Golang
# 130         130           PostgreSQL, Linux, Unix, Golang, Go, SSL
# 131         131                   Golang, Docker, PostgreSQL, gRPC
# 132         132           SQL, C++, Движение денежных средств, ООП
# 133         133                                                NaN
# 134         134  Русский — B2 — Средне-продвинутый, Английский ...
# 135         135  Английский — B1 — Средний, AWS, MongoDB, JavaS...
# 136         136           Linux, Git, Docker, SQL, Английский язык
# 137         137   Golang, PostgreSQL, REST, Git, GRPC, Docker, SQL
# 138         138  Русский — B2 — Средне-продвинутый, Английский ...
# 139         139  SQL, Английский язык, PostgreSQL, XML, Работа ...
# 140         140           Git, C#, SQL, Golang, golang, go, Django
# 141         141                      Golang, Go, PostgreSQL, Redis
# 142         142              Golang, Linux, Go, Kubernetes, Docker
# 143         143  C#, Go, Golang, PostgreSQL, Redis, Docker, Rab...
# 144         144                       MySQL, Git, PHP, SQL, Golang
# 145         145         Git, Golang, JavaScript, MySQL, PostgreSQL
# 146         146              Golang, Linux, Go, Kubernetes, Docker
# 147         147  Английский — C1 — Продвинутый, Linux, Git, Red...
# 148         148                 Python, Git, MongoDB, Redis, Unity
# 149         149                                                NaN
# 150         150                                         Go, Python
# 151         151              Golang, Linux, Go, Kubernetes, Docker
# 152         152  Английский — A1 — Начальный, Java, PostgreSQL,...
# 153         153  Английский — B1 — Средний, Python, PostgreSQL,...
# 154         154              Golang, Linux, Go, Kubernetes, Docker
# 155         155  Linux, C++, C++ boost, Алгоритмы и структуры д...
# 156         156  PostgreSQL, SQL, Django Framework, Kafka, go, ...
# 157         157  Английский — B2 — Средне-продвинутый, JavaScri...
# 158         158      Linux, PostgreSQL, PHP, Java, Английский язык
# 159         159                             PHP, Laravel, ОПП, SQL
# 160         160      Python, MongoDB, Django Framework, Git, Linux
# 161         161         React, Vue, JavaScript, jQuery, Typescript
# 162         162  Английский — B1 — Средний, Node.js, JavaScript...
# 163         163     Английский — A1 — Начальный, REST API, Backend
# 164         164            JavaScript, Git, MySQL, PostgreSQL, PHP
# 165         165                PHP, Git, MySQL, docker, go, golang
# 166         166  Python, Git, PostgreSQL, Django Framework, SQL...
# 167         167                PHP, Git, MySQL, docker, go, golang
# 168         168     SQL, JavaScript, Git, PHP, XML, GoLang, Python
# 169         169                         AWS, Docker, Python, Linux
# 170         170                           Git, Ruby, Ruby On Rails
# 171         171  Golang, MySQL, HTML, CSS, ООП, JavaScript, Typ...
# 172         172                         AWS, Docker, Python, Linux
# 173         173  Английский — B1 — Средний, Linux, Java, Kubern...
# 174         174                  Linux, Python, Ansible, Bash, AWS
# 175         175                   Git, Ruby On Rails, Docker, Ruby
# 176         176   MongoDB, PostgreSQL, Node.js, MySQL, PHP, Golang
# 177         177                                                NaN
# 178         178  Английский — A1 — Начальный, PHP, Symfony, ООП...
# 179         179  Английский — A1 — Начальный, JavaScript, Node....
# 180         180  Английский — B1 — Средний, Terraform, Английск...
# 181         181                     Python, SQL, PHP, Java, Golang
# 182         182                        Английский — A1 — Начальный
# 183         183  JUnit, Java, Zuul, Kafka, Gradle, Spring, WebS...
# 184         184         Docker, Golang, Bash, Python, Unix, Gitlab
# 185         185  Английский — B2 — Средне-продвинутый, Python, ...
# 186         186                                                NaN
# 187         187  Функциональное тестирование, HTML, XML, REST A...
# 188         188  Linux, Docker, Python, PostgreSQL, MySQL, Bash...
# 189         189  JavaScript, Node.js, PostgreSQL, jQuery, Git, ...
# 190         190  Nginx, Docker, MongoDB, Git, Kubernetes, *nix,...
# 191         191                                                NaN
# 192         192  Английский — A1 — Начальный, PHP, Golang, dock...
# 193         193  Linux, Bash, Python, Английский язык, Деловая ...
# 194         194        Ansible, Bash, Linux, Kubernetes, Terraform
# 195         195        Ansible, Bash, Linux, Kubernetes, Terraform
# 196         196  Английский язык, Golang, Креативность, Многоза...
# 197         197                          PHP, Gitlab, Docker, Jira
# 198         198  Git, MySQL, Laravel, HTML, SQL, ООП, phpMyAdmi...
# 199         199  JavaScript, PostgreSQL, Redis, PHP, Laravel, E...
# 200         200                  PHP, PostgreSQL, SQL, Docker, ООП
# 201         201  Английский — B1 — Средний, SQL, Английский язы...
# 202         202  ООП, Git, PHP, PostgreSQL, SQL, Laravel, Golan...
# 203         203  JavaScript, Python, PHP, SQL, MS SQL, IT, HR, ...
# 204         204            Linux, MySQL, Golang, Git, Symfony, PHP
# 205         205  Разработка нового продукта, Базы данных, REST,...
# 206         206  JavaScript, Python, PHP, SQL, MS SQL, IT, HR, ...
# 207         207  Python, MongoDB, Redis, PostgreSQL, Swagger, C...
# 208         208          Git, MySQL, PHP, Docker, Magento, Laravel
# 209         209  Backend, Kubernetes, Python, Docker, Linux, Go...
# 210         210  Английский — B1 — Средний, Git, Node.js, MySQL...
# 211         211                                                NaN
# 212         212                                                NaN
# 213         213  DevOps, Scrum, Python, Atlassian Jira, Английс...
# 214         214  Тестирование, Техническая документация, Подгот...
# 215         215            Linux, MySQL, Git, Golang, Symfony, PHP
# 216         216  Docker, PostgreSQL, Nginx, Golang, Redis, CI/C...
# 217         217  Docker, PostgreSQL, Nginx, Golang, Redis, CI/C...
# 218         218  Docker, PostgreSQL, Nginx, Golang, Redis, CI/C...
# 219         219  Docker, PostgreSQL, Nginx, Golang, Redis, CI/C...
# 220         220  Kubernetes, Linux, Docker, Golang, GitOps, CI/...
# 221         221  Docker, Английский язык, PostgreSQL, TypeScrip...
# 222         222  Английский — B1 — Средний, C#, Git, JSON API, ...
# 223         223  Redis, Python, MySQL, PostgreSQL, Git, PHP, go...
# 224         224        Git, MongoDB, Английский язык, ООП, SQL, C#
# 225         225        Git, MongoDB, Английский язык, ООП, SQL, C#
# 226         226  Linux, Python, quagga, Puppet, ansible, promet...
# 227         227  Linux, Python, quagga, Puppet, ansible, promet...
# 228         228  Linux, Python, quagga, Puppet, ansible, promet...
# 229         229  Linux, Python, quagga, Puppet, ansible, promet...
# 230         230  Linux, Python, quagga, Puppet, ansible, promet...
# 231         231  Linux, Python, quagga, Puppet, ansible, promet...
# 232         232                                PHP, Laravel, MySQL
# 233         233                         Разработка нового продукта
# 234         234                Git, ООП, PHP, Linux, MySQL, Golang
# 235         235                                                NaN
# 236         236  Python, PostgreSQL, Docker, Java, SQL, DWH, TC...
# 237         237  Английский — B1 — Средний, Kubernetes, Docker,...
# 238         238  Английский — B1 — Средний, Kubernetes, Docker,...
# 239         239  Английский — B1 — Средний, Kubernetes, Docker,...
# 240         240  Английский — B1 — Средний, Kubernetes, Docker,...
# 241         241  Linux, Git, Kubernetes, Python, Golang, Java, ...
# 242         242  Linux, Git, Kubernetes, Python, Golang, Java, ...
# 243         243            Linux, MySQL, Golang, Git, Symfony, PHP
# 244         244                        Java, Spring Framework, ООП
# 245         245  Git, Node.js, Английский — B1 — Средний, JavaS...
# 246         246  Git, Node.js, Английский — B1 — Средний, JavaS...
# 247         247  Git, Node.js, Английский — B1 — Средний, JavaS...
# 248         248  DevOps, Python, Scrum, Atlassian Jira, SQL, C#...
# 249         249  Английский — B1 — Средний, PostgreSQL, Node.js...
# 250         250  Git, PHP, JavaScript, Bootstrap, 1С-Битрикс, L...
# 251         251                                                NaN
# 252         252  Английский — A2 — Элементарный, MySQL, Git, Sy...
# 253         253                     PostgreSQL, Python, Go, Golang
# 254         254          Golang, PostgreSQL, Docker, Python, Scrum
# 255         255  PostgreSQL, Scrum, Golang, Управление командой...
# 256         256                  PostgreSQL, PHP, Yii2, Linux, Git
# 257         257                 PostgreSQL, Linux, Golang, ФИНАНСЫ
# 258         258                 PostgreSQL, Linux, Golang, ФИНАНСЫ
# 259         259  PostgreSQL, Python, Docker, SQL, DevOps, Kuber...
# 260         260        C#, .NET Framework, ASP.NET MVC, ООП, SOLID
# 261         261                Работа в команде, Мотивация, golang
# 262         262  React, PHP, JavaScript, Web Application Develo...
# 263         263  JavaScript, Node.js, PostgreSQL, jQuery, Git, ...
# 264         264  JavaScript, Node.js, PostgreSQL, jQuery, Git, ...
# 265         265  JavaScript, Node.js, PostgreSQL, jQuery, Git, ...
# 266         266                Git, PostgreSQL, Docker, C#, Golang
# 267         267  Linux, Git, Kubernetes, Python, Golang, Java, ...
# 268         268          Golang, Docker, Kubernetes, gRPC, MongoDB
# 269         269  Английский — B1 — Средний, Python, PostgreSQL,...
# 270         270  Английский — B1 — Средний, PostgreSQL, Node.js...
# 271         271  Английский язык, Grafana, PHP, Laravel, Symfon...
# 272         272                                                NaN
# 273         273   Python, PostgreSQL, Django Framework, Redis, Git
# 274         274  PostgreSQL, Python, Django Framework, Git, Red...
# 275         275  Тестирование, Техническая документация, Подгот...
# 276         276             Python, Django Framework, MySQL, Linux
# 277         277  Golang, go, Docker, API, RabbitMQ, Kafka, Memc...
# 278         278  Английский — B1 — Средний, Python, Kubernetes,...
# 279         279                                                NaN
# 280         280  Python, Linux, SQL, ООП, Английский язык, Kube...
# 281         281  Python, Linux, SQL, ООП, Английский язык, Kube...
# 282         282                                                NaN
# 283         283  SQL, MS SQL, Golang, Лидерство, руководство ко...
# 284         284  Kubernetes, Docker, Linux, ELK, Zabbix, Grafan...
# 285         285  DevOps, CI/CD, Unix, Git, Terraform, Docker, K...
#
#                                                   name        id  \
# 0                   Middle / Senior Golang разработчик  50329861
# 1                                     Golang Developer  51762805
# 2                              Golang Middle developer  52160078
# 3    Senior/middle Golang developer/teamlead in-hou...  52147568
# 4                       Middle Go / Golang разработчик  50939243
# 5    Senior golang-developer / Middle GO разработчи...  51414397
# 6                              Middle GoLang developer  52182894
# 7         Middle Golang developer / Программист Golang  51107108
# 8    Blockchain разработчик/Frontend-разработчик/Fu...  50977645
# 9                              Golang Middle developer  50889327
# 10                           Golang Developer (middle)  52024197
# 11          Backend Middle разработчик (Python/Golang)  51264835
# 12                           GoLang Middle разработчик  45430651
# 13                    Golang-разработчик в Маркетплейс  51632612
# 14                                  Golang разработчик  50825858
# 15                           Golang developer (middle)  50951017
# 16                       Go (Golang) Backend Developer  49948028
# 17                             Golang middle developer  46990013
# 18                             Middle Golang developer  50864259
# 19                             Golang Middle developer  50861971
# 20                             Golang Middle Developer  52165490
# 21                             Golang middle developer  49321541
# 22                                    Python Developer  51160195
# 23                              PHP Developer (middle)  52024759
# 24                             Middle Golang Developer  52160690
# 25                                 Middle Go Developer  50655841
# 26                                    Python Developer  51160196
# 27                           Python developer (Middle)  51183293
# 28                          Backend Developer (Golang)  52112106
# 29   Python разработчик (senior) (backend)/ Backend...  43941903
# 30         Backend разработчик Golang (Middle, Senior)  52122155
# 31                      Middle/Senior Golang Developer  50715860
# 32                      Middle/senior Golang developer  50831952
# 33                    Middle Python / Golang developer  51617308
# 34                         Golang-разработчик (middle)  52120406
# 35   Senior/Middle Golang Developer ( Senior/Middle...  50603493
# 36                             Golang middle developer  49321445
# 37                           Golang developer (Middle)  42999039
# 38                             Golang middle developer  49321493
# 39                      Middle/senior Golang developer  50769962
# 40   Golang-разработчик в Сервис для бронирования о...  51406030
# 41                                    Golang Developer  47300910
# 42                      Middle/senior Golang developer  50831052
# 43                      Middle/Senior Golang Developer  50715904
# 44                            Middle Backend Developer  52097442
# 45                    Golang-Developer Middle / Senior  47975526
# 46                      Middle/Senior Golang Developer  50715829
# 47                PHP/Golang-Developer Middle / Senior  42777355
# 48            Middle / middle+ веб-разработчик Laravel  51985723
# 49   Middle / Senior / Principle Golang Developer, ...  52112610
# 50                         Middle/Senior C++ Developer  42397159
# 51                          Middle/Senior Go Developer  47504849
# 52                        Backend разработчик (Middle)  50926433
# 53                      Middle/Senior Golang developer  50835097
# 54                      Middle/Senior Golang Developer  51401831
# 55                             Middle Python Developer  50894235
# 56                    Golang-developer (Middle/Senior)  52031733
# 57                      Middle\Senior PHP -разработчик  52011329
# 58                         Middle/Senior C++ Developer  51050669
# 59                                        Go Developer  50511988
# 60           Middle/Senior Golang Developer (удаленно)  52005182
# 61                   Lead/Senior/Middle Rust Developer  50789953
# 62            Middle/Senior Golang Developer (Banking)  52161627
# 63               Junior/Middle/Senior Golang Developer  47722398
# 64                          Главный разработчик Golang  51419219
# 65   Golang разработчик (решения видеонаблюдения/CCTV)  50946580
# 66                                 Go/Python developer  52020360
# 67                           Back-end developer Golang  49946264
# 68                  PHP/Go разработчик (middle/senior)  50214795
# 69             Backend PHP Developer / РHP Разработчик  50738941
# 70                           Middle Golang разработчик  51918282
# 71                                          Middle SRE  51799026
# 72                      Middle/Senior Golang developer  51831339
# 73              Разработчик Golang / Python ( Middle )  43775356
# 74                           PHP - Laravel Разработчик  51742965
# 75               Middle backend developer (blockchain)  52074289
# 76                      Middle/Senior Golang Developer  51766504
# 77              Node.JS - разработчик (middle, senior)  50114283
# 78       Middle/Senior Full-Stack Javascript Developer  51360765
# 79                            Middle Backend Developer  51001618
# 80          Web-разработчик (Fullstack, Junior/Middle)  51725584
# 81                      Middle/senior Golang developer  50863518
# 82                             Middle Python Developer  39266383
# 83                                Go Developer, Middle  50587113
# 84   Middle/ Middle + Golang разработчик ( VPN mana...  51656395
# 85                      Middle\Senior PHP -разработчик  51885162
# 86               Frontend-разработчик (Angular/Middle)  51249668
# 87             Middle +/Senior Ruby on Rails developer  43161597
# 88               Backend PHP developer (Middle/Senior)  44355457
# 89   Junior/Middle Go developer (Blockchain integra...  51992888
# 90                  Golang-разработчик / Middle/Senior  51667031
# 91        Middle backend developer (ML Space AI Cloud)  47722295
# 92                             Middle golang developer  42267653
# 93   Middle React разработчик для компании-разработ...  51614029
# 94            PHP Backend разработчик (Middle/Middle+)  51361576
# 95                  Middle Golang разработчик в Товары  51334263
# 96                                  Golang-разработчик  51924637
# 97                  Middle Golang разработчик в Товары  51332766
# 98                      Senior\Middle Golang developer  51500269
# 99                  Middle Golang разработчик в Товары  51334404
# 100                   Middle Golang developer (Москва)  50547902
# 101                 Middle Golang разработчик в Товары  51333843
# 102                 Middle Golang разработчик в Товары  51334004
# 103                              Разработчик на Golang  51360177
# 104                        Разработчик на Golang (553)  51270333
# 105                            Middle Golang Developer  51278379
# 106   Software Engineer (Golang) / Backend-разработчик  51438362
# 107                 Middle Golang разработчик в Товары  51334468
# 108                   Golang Developer (Senior/Middle)  51218924
# 109                        Программист Python (Middle)  50984438
# 110                               Middle/Senior Golang  50662420
# 111              Golang Developer / Golang разработчик  51353550
# 112                   Middle Golang/Python-разработчик  50985019
# 113                             Middle PHP Разработчик  51884035
# 114                       Fullstack Developer (Golang)  50096832
# 115                             Middle PHP Разработчик  51884034
# 116                             Middle PHP Разработчик  51884036
# 117              Разработчик Golang (middle, удаленно)  51029290
# 118                            Middle Golang developer  48586743
# 119                    Go backend-разработчик (Middle)  51602570
# 120                          Middle Golang-разработчик  51040829
# 121       Middle/Senior Golang Developer (шина данных)  51364946
# 122            Middle / Senior Разработчик С++ (linux)  48306331
# 123                     Middle/Senior Golang Developer  49818424
# 124                 Разработчик Golang (Middle/Senior)  50865610
# 125                        Senior/ Middle GO developer  50422692
# 126         Backend разработчик GoLang (Middle/Senior)  50837784
# 127            Middle, Senior Go(Golang)/PHP developer  50869045
# 128                                       Go Developer  50914112
# 129                           Middle Backend Developer  49512290
# 130                     Golang developer middle/senior  50943709
# 131                Middle backend разработчик (Golang)  46346476
# 132                    Junior+/Middle Golang Developer  50929948
# 133         Middle/Senior GoLang developer (core team)  49518470
# 134                                   Golang Developer  51009769
# 135                             Middle Golang Engineer  51086175
# 136            Middle бэкенд-разработчик (Python, C++)  51903221
# 137  Middle Golang developer, дистанционно (Владиво...  50808570
# 138                                       Go Developer  51435025
# 139                          Middle golang-разработчик  51174204
# 140                           Middle Backend Developer  39971918
# 141                                 GoLand разработчик  49441311
# 142  Middle/Senior Golang Developer (Sber Virtualiz...  50929069
# 143             Middle/senior .Net Backend разработчик  48010679
# 144                     Middle Backend Developer (PHP)  51102047
# 145                   Middle Fullstack Developer (PHP)  51102316
# 146  Middle/Senior Golang Developer (Sber Virtualiz...  50929070
# 147                                   Golang Developer  50866106
# 148                  Middle Backend Developer (Python)  51277791
# 149                     Middle/Senior PHP/Go Developer  49649153
# 150                Go/Python Developer (middle/senior)  49784403
# 151  Middle/Senior Golang Developer (Sber Virtualiz...  50929071
# 152            Java Backend Software Engineer (Middle)  51718290
# 153                            Middle Python developer  51165728
# 154  Middle/Senior Golang Developer (Sber Virtualiz...  50929072
# 155                        Middle/Senior C++ Developer  50768747
# 156                         Backend Developer (Golang)  49883107
# 157               Full Stack Developer (Middle/Senior)  50880065
# 158                          Backend (PHP) разработчик  51346753
# 159  Middle PHP программист (Laravel) продуктовая р...  51108988
# 160                 Python разработчик (middle/senior)  43961654
# 161  Middle Frontend Developer / Разработчик JavaSc...  51918609
# 162                         Middle Backend разработчик  37423597
# 163           Backend-разработчик/программист (middle)  51170700
# 164                    Веб разработчик (Middle-Senior)  51991011
# 165                        Разработчик PHP/Go (Middle)  51983631
# 166                          Python developer (Middle)  51279806
# 167                        Разработчик PHP/Go (Middle)  52123976
# 168                       Middle фулл стэк разработчик  49815512
# 169       Middle DevOps Engineer (Customization Blitz)  50628036
# 170                          Ruby on Rails разработчик  49913947
# 171                         Middle Backend-разработчик  47860338
# 172       Middle DevOps Engineer (Customization Blitz)  50628035
# 173  Middle/Senior/Principal Java Developer (K8s), ...  51256143
# 174                                    DevOps Engineer  51656462
# 175                          Ruby on Rails разработчик  50593648
# 176            Middle/Senior developer (Go) (СберДиск)  52173287
# 177                    Веб-разработчик (Junior-middle)  49727510
# 178                      PHP-Developer Middle / Senior  46193809
# 179             Node.JS - разработчик (middle, senior)  44689860
# 180                    Middle / Senior DevOps Engineer  51351688
# 181                  Middle QA Manual / Тестировщик ПО  51647409
# 182                                      Data Engineer  48501169
# 183                  Java-разработчик / Middle/ Senior  52121001
# 184                                     DevOps инженер  47661620
# 185       Middle Backend Engineer (Remote, Relocation)  50992783
# 186                            DevOps-инженер (Middle)  50370297
# 187                                 Middle QA Engineer  50890539
# 188                      Middle/Senior DevOps Engineer  52145017
# 189             Node.JS - разработчик (middle, senior)  46640198
# 190                              Middle DevOps-инженер  50371083
# 191   Middle/Senior Vue.js Engineer, Marketing Startup  51713575
# 192                 Middle developer (программист PHP)  52094173
# 193                            Инженер DevOps (Middle)  47178928
# 194                            Инженер DevOps (Middle)  50064873
# 195                            Инженер DevOps (Middle)  50064748
# 196                Team Lead Backend в команду Tariffs  50844121
# 197      PHP-разработчик (PHP-developer) Middle/Senior  52072801
# 198                               Middle PHP Developer  50712883
# 199                       Middle PHP/Laravel Developer  52023921
# 200              Инженер-программист ( Middle Backend)  50997844
# 201          Senior Backend Developer (Blockchain Lab)  52062402
# 202              Middle/Senior Backend Developer (PHP)  52046446
# 203                         Senior IT HR (Only Hiring)  51287867
# 204                               Middle PHP Developer  52005347
# 205                             Java Backend Developer  49936806
# 206                         Senior IT HR (ИТ рекрутер)  51794798
# 207        Python-разработчик / Middle/Senior/TechLead  51970310
# 208                      Middle Fullstack PHP Engineer  50792449
# 209       Senior backend developer (ML Space AI Cloud)  47722267
# 210         Разработчик бэкэнда в Санкт-Петербург (Go)  51938940
# 211                                    DevOps engineer  48884433
# 212                                        Программист  51952354
# 213  Специалист по автоматизированному тестированию...  51954102
# 214          Middle Тестировщик ПО / QA engineer (Уфа)  41969566
# 215                               Middle PHP Developer  51892900
# 216                         DevOps Specialist (Middle)  47152829
# 217                         DevOps Specialist (Middle)  48902158
# 218                         DevOps Specialist (Middle)  48902236
# 219                         DevOps Specialist (Middle)  48902226
# 220                                     DevOps инженер  51879360
# 221       Middle-Senior Software Developer / Team Lead  51851382
# 222    Разработчик (Senior/Middle Web-Developer) C#/Go  50731213
# 223                                   Middle developer  51984624
# 224                   Middle разработчик C# (удаленно)  51831215
# 225                   Middle разработчик C# (удаленно)  51831178
# 226           Middle Systems Engineer (CDN Operations)  51837715
# 227           Middle Systems Engineer (CDN Operations)  51837714
# 228           Middle Systems Engineer (CDN Operations)  51837711
# 229           Middle Systems Engineer (CDN Operations)  51837713
# 230           Middle Systems Engineer (CDN Operations)  51837716
# 231           Middle Systems Engineer (CDN Operations)  51837712
# 232                   Backend developer (php, laravel)  51761773
# 233                     Team Lead (Авито Недвижимость)  50298096
# 234                    PHP разработчик (Middle/Senior)  51715882
# 235                            DevOps-инженер (Middle)  49442281
# 236                                 Middle DWH инженер  51697373
# 237                                    DevOps Engineer  51706723
# 238                                    DevOps Engineer  51706721
# 239                                    DevOps Engineer  51706722
# 240                                    DevOps Engineer  51706720
# 241                    Site Reliability Engineer (SRE)  51711376
# 242                    Site Reliability Engineer (SRE)  51710770
# 243                               Middle PHP Developer  51646315
# 244                     Middle/Senior Java-разработчик  51637413
# 245        Middle Backend разработчик, Санкт-Петербург  47879341
# 246        Middle Backend разработчик, Санкт-Петербург  47879340
# 247        Middle Backend разработчик, Санкт-Петербург  47879339
# 248  Ведущий специалист по автотестированию /QA aut...  51135770
# 249                               Middle PHP developer  45845577
# 250                                    Программист PHP  51643528
# 251                   Middle/Senior penetration tester  47338998
# 252    PHP разработчик (Symfony php backend developer)  51511407
# 253             Python Team Leader (переход на Golang)  51329899
# 254                PHP Team Leader (переход на Golang)  51344473
# 255                            GO (golang) Team Leader  50730156
# 256                       Backend-разработчик (Middle)  44945647
# 257  Разработчик (Go) в Ozon Bank / Разработка ядра...  51406863
# 258  Разработчик Go в Ozon Bank / Разработка ядра и...  51406864
# 259                              Middle DevOps инженер  51411337
# 260                                     Программист C#  51402454
# 261          Тимлид разработки в команду Core Services  51416837
# 262                        Junior/Middle Web developer  51321338
# 263             Node.JS - разработчик (middle, senior)  49535536
# 264             Node.JS - разработчик (middle, senior)  51334282
# 265             Node.JS - разработчик (middle, senior)  49909394
# 266                        Backend Developer (FinTech)  51269077
# 267                    Site Reliability Engineer (SRE)  51708502
# 268  Middle Go Developer в команду инфосервисов сер...  48246427
# 269                                   Python developer  51165436
# 270                               Middle PHP developer  48685512
# 271                          Back-end разработчик, PHP  51174592
# 272  Middle Go Developer в команду SEO сервиса путе...  50062841
# 273                                 Python-разработчик  48463982
# 274                 Python разработчик (Middle/Senior)  47016117
# 275  Middle Тестировщик ПО / QA engineer Дистанцион...  50808527
# 276                                   Python Developer  46331257
# 277         Ведущий разработчик Go/Senior Go Developer  51093734
# 278                        Software Python/Go engineer  50998205
# 279                 QA manual в международную компанию  51039764
# 280  Middle/Senior Python Developer (Platform Virtu...  50930369
# 281  Middle/Senior Python Developer (Platform Virtu...  50930370
# 282                             Автотестировщик (java)  50963703
# 283                                          Tech lead  51401559
# 284            DevOps Engineer в онлайн-кинотеатр KION  48548113
# 285                   DevOps инженер (middle / senior)  51285498
#
#                                            description  \
# 0    Команда **КИБЕР-РОМ** — это ИТ-проект, которыи...
# 1    Наша команда уже несколько лет занимается созд...
# 2    **Мы — команда молодых и амбициозных разработч...
# 3    Цифровая команда "Технониколь" разрабатывает б...
# 4    Привет!Мы занимаемся разработкой сложных и ин...
# 5    **ООО «Системы распределенного реестра»** – пе...
# 6    OTM — высоконагруженный сервис (300+ млрд зап...
# 7    **Lenvendo** на протяжении 15 лет занимается с...
# 8    xDAO — конструктор для создания и управления д...
# 9    **Международная компания B2Broker (Business to...
# 10   **Проект под который мы ищем разработчика:** ...
# 11    **Обязанности:**  * Участие в разработке веб-...
# 12   **Международная компания B2Broker (Business to...
# 13   Golang-разработчик в высоконагруженный Маркет...
# 14    **KVANDO Technologies****ЗП: 130 000 - 220 00...
# 15    ** _Мы интернет-компания, наши команды заняты...
# 16   Команда **Evrone** занимается продуктовой раз...
# 17    **Сохраняем здоровье и заботимся о людях!**"А...
# 18    **Расширяем команду нашего действующего прое...
# 19   **Международная компания B2Broker (Business to...
# 20   Messaggio.com - сервис мультиканальной рассыл...
# 21    **Сохраняем здоровье и заботимся о людях!**"А...
# 22     АСД Технолоджиз, разработчик платформы cloud...
# 23   **Обязанности:**\- поддержка и развите сервиса...
# 24   Привет!Мы компания **Quadcode** , разрабатывае...
# 25   **RollerAds** — международная Ad-Tech компания...
# 26     АСД Технолоджиз, разработчик платформы cloud...
# 27   Python разработчик (Middle) с опытом от 2,5 ле...
# 28   OUTSIDE требуется опытный специалист по backe...
# 29   Ищем активного человека с опытом написания раз...
# 30   Привет!Меня зовут Алан, я рекрутер команды Hol...
# 31   В *Instinctools открыта вакансия **Middle/Seni...
# 32   **О ПРОЕКТЕ:** Здравсити - это сервис заказа а...
# 33   У команды **SberAutoTech** есть цель, и это – ...
# 34   Мы знаем, что такое монолит и активно развивае...
# 35   Мы делаем технически сложный highload проект....
# 36   **Сохраняем здоровье и заботимся о людях!**"Ап...
# 37   Финтех-компания **FBS** – разработчик программ...
# 38    **Сохраняем здоровье и заботимся о людях!**"А...
# 39    **О ПРОЕКТЕ:** Здравсити - это сервис заказа ...
# 40   Команда **Evrone** занимается продуктовой раз...
# 41    **WILDBERRIES** — это крупнейший российски...
# 42   **О ПРОЕКТЕ:** Здравсити - это сервис заказа а...
# 43   В *Instinctools открыта вакансия **Middle/Seni...
# 44   «Volga-volga» - объединение классных людей в ...
# 45   _Garage Eight – международная продуктовая IT-к...
# 46   В *Instinctools открыта вакансия **Middle/Seni...
# 47   _Garage Eight – международная продуктовая IT-к...
# 48   Диджитал-агентству нужен middle или middle+ бэ...
# 49   **Senior Microservices/K8s Developer, Common M...
# 50   _Scalable Solutions – международная технологич...
# 51   **Обязанности:**  * Разрабатывать новые и улуч...
# 52   Наша компания, специализируется на электроннои...
# 53   Мы - **Pushwoosh** – глобальный хайлоад прод...
# 54   Внутри Лаборатории есть масса сервисов и множе...
# 55   **«Наши платежи драйвят бизнес»** — это не пр...
# 56   **Тебе хочется работать с интересными и увлека...
# 57   В проект SearchBooster.io ищем ведущего бекенд...
# 58    _Scalable Solutions – международная технологи...
# 59   Мы формируем команду Go-программистов и выделя...
# 60   Требуется Golang-разработчик уровня Middle/Sen...
# 61   Algalon Capital is looking to hire a Lead/Seni...
# 62   Привет!Мы компания **Quadcode** , разрабатывае...
# 63   **Вам предстоит:**  * Разработка продуктов обл...
# 64   Ищем Golang разработчика на один из наших прое...
# 65   **Чем предстоит заниматься:**  * Разработкой ...
# 66   ​ **В классную финтех-компанию ищем Middle/Sen...
# 67   **НОВЫЙ АКТИВ ГАЗПРОМ МЕДИА ХОЛДИНГА СОЗДАЕТ ...
# 68   ООО "Защищенные телекоммуникации" \- IT-компан...
# 69   Мы IT-компания в сфере adtech и gamedev.  Созд...
# 70   Добрый день! Наш заказчик - международная ком...
# 71   Платформа **InSales** – это профессиональная о...
# 72   Команда разработчиков Lab365 в поисках Golang ...
# 73   Обязанности:  \- Разработка программного обесп...
# 74   **Middle, Senior / Team lead / PHP Разработчик...
# 75   В связи с активным развитием продуктового напр...
# 76   Наша команда уже несколько лет занимается созд...
# 77    **Международная IT-компания SoftGamings пригл...
# 78   Мы расширяемся и приглашаем в команду разработ...
# 79   Мы предлагаем работу над системой, которая св...
# 80   Novastar — небольшая частная компания, основан...
# 81   **О ПРОЕКТЕ:** Здравсити - это сервис заказа а...
# 82    _ **КОМАНДА РАЗРАБОТКИ ПЛАТФОРМЕННЫХ РЕШЕНИЙ...
# 83   **RetailCRM —** передовое SaaS-решение для eCo...
# 84   **МТС – одна из крупнейших российских технол...
# 85   В проект SearchBooster.io ищем ведущего бекенд...
# 86   Финтех компания Bankex в поисках Frontend-разр...
# 87   **Roonyx - международная компания по разработк...
# 88   **CityAds Media** – глобальный партнер по мар...
# 89   **Мы — TechHub криптовалютной платформы EXMO....
# 90   _Привет!__Мы ищем Backend-разработчика, которы...
# 91   Приглашаем **Middle Backend Developer** в кома...
# 92   Приглашаем к себе в команду **Middle backend d...
# 93   В настоящее время мы ищем **удалённого** **Mi...
# 94   Привет! Тебе нравятся **интересные и нестандар...
# 95   Мы ищем backend-разработчика, который будет в...
# 96   ” **FLEETCOR** ” – мировой лидер в области пр...
# 97   Мы ищем backend-разработчика, который будет в...
# 98   Мы — команда разработчиков в крупнейшем марке...
# 99   Мы ищем backend-разработчика, который будет в...
# 100  **TagesJump работает на рынке IT с 2012 года. ...
# 101  Мы ищем backend-разработчика, который будет в...
# 102  Мы ищем backend-разработчика, который будет в...
# 103  Кадровое агентство ищет разработчика Golang в ...
# 104  Кадровое агентство ищет разработчика Golang в ...
# 105   **Skipp** – стремительно растущий международ...
# 106  AURA Devices — разрабатывает носимую электрони...
# 107  Мы ищем backend-разработчика, который будет в...
# 108  **О компании и проекте:**Технологичный америк...
# 109  В команду, занимающуюся разработкой распредел...
# 110  Мы ищем уверенного в себе Golang-разработчика ...
# 111  Ищем **Middle или Senior Golang разработчика**...
# 112  В команду, занимающуюся разработкой распредел...
# 113  **Zaymigo -** это современная FinTech компания...
# 114  «РЕЗОНИТ» является крупнейшим производителем ...
# 115   **Zaymigo -** это современная FinTech компани...
# 116  **Zaymigo -** это современная FinTech компания...
# 117  В компанию-разработчик софта для нефтяного сек...
# 118  Мы — команда разработчиков в крупнейшем марке...
# 119  **Обязанности:**  * реализациея новых фич в пр...
# 120  «Интерсвязь» — одна из крупнейших IT-компании...
# 121   **Привет!**Мы компания **Quadcode,** разрабат...
# 122  **Разработчик Middle/Senior С++ (** **linux** ...
# 123  _Since 2011, Emerline has operated as a part o...
# 124  В команду по разработке сервиса партнерских по...
# 125  « **АЙТЕКО** » — одна из крупнейших российс...
# 126  Мы **** создаем эко-систему для рынка продукто...
# 127  Международный сервис пассажирских и грузовых ...
# 128  Мы, команда xpate - создаем продукт, с помощью...
# 129  **Product**Evercon is top 3 startup by investm...
# 130   **Мы:**ГК ХайТэк - разрабатываем систему уни...
# 131  **GS Labs** (в составе холдинга GS Group) – це...
# 132  **Привет!** Мы – томская IT-компания SMART WOR...
# 133  **Мы -- TechHub криптовалютной платформы EXMO...
# 134  Мы ищем уверенного в себе Golang-разработчика ...
# 135  IDT is looking for a **Mid-Level Golang Softwa...
# 136  Мы ищем **Middle бэкенд-разработчика** в коман...
# 137  **TagesJump работает на рынке IT с 2012 года. ...
# 138  Мы ищем уверенного в себе Golang-разработчика ...
# 139  Ищем **Middle golang-разработчика** в крупней...
# 140  В дружную команду профессионалов интересного р...
# 141  **theMAP** – это международный платёжный се...
# 142  **Вам предстоит:**  * Разрабатывать и поддержи...
# ...
# 152                                       Prime Source  FULL_DAY
# 153                                                FIX  FULL_DAY
# 154                                          SberCloud  FULL_DAY
# 155                           Кадровое агентство Юнити  FLEXIBLE
# 156                                          РОССТ, РА  FULL_DAY
# 157                                    NAPA AUTOMOTIVE  FLEXIBLE
# 158                                Селадон девелопмент  FULL_DAY
# 159                                        РусПерсонал    REMOTE
# 160                                            НТехЛаб    REMOTE
# 161                                           Софтвайс  FULL_DAY
# 162                                   Reelmotion games  FULL_DAY
# 163                                            Гет-Нэт  FULL_DAY
# 164                                                 OQ  FULL_DAY
# 165                                           Carprice    REMOTE
# 166                                             Диэсэл  FLEXIBLE
# 167                                           Carprice    REMOTE
# 168                                         Кривец С.С  FULL_DAY
# 169                                  Wargaming, Moscow  FULL_DAY
# 170                                             NAUMEN    REMOTE
# 171                                            НЕОСОФТ  FULL_DAY
# 172                                  Wargaming, Moscow  FULL_DAY
# 173                Dell Technologies, Центр Разработок  FULL_DAY
# 174                                      РД Технологии  FLEXIBLE
# 175                                             NAUMEN    REMOTE
# 176                                          SberCloud  FULL_DAY
# 177                                                 OQ  FULL_DAY
# 178                                       Garage Eight  FULL_DAY
# 179                                        SoftGamings  FULL_DAY
# 180                                    Gemini Advisory    REMOTE
# 181                                             Телега    REMOTE
# 182                                        WILDBERRIES    REMOTE
# 183                                               KODE    REMOTE
# 184                                 Энерджи Консалтинг    REMOTE
# 185                                    Citadel ID Inc.  FULL_DAY
# 186                 CCS (Center of Corporate Solution)  FULL_DAY
# 187                                          Константа  FLEXIBLE
# 188                               Hearst Shkulev group  FULL_DAY
# 189                                        SoftGamings  FULL_DAY
# 190                                            4people  FULL_DAY
# 191                                            DataArt  FLEXIBLE
# 192                                    Ticketon Events  FULL_DAY
# 193                              Прикладные технологии    REMOTE
# 194                              Прикладные технологии    REMOTE
# 195                              Прикладные технологии    REMOTE
# 196                                          АВИТО ТЕХ  FULL_DAY
# 197                                  Siberian Wellness  FULL_DAY
# 198                                           Инвольта  FLEXIBLE
# 199                                           Сайтсофт  FULL_DAY
# 200                                             ГК TFN    REMOTE
# 201                                           Сбер. IT  FLEXIBLE
# 202                                          A3F Group  FULL_DAY
# 203                                                GRI    REMOTE
# 204                                          Marfatech  FULL_DAY
# 205                                          OutStream    REMOTE
# 206                                                GRI    REMOTE
# 207                                               KODE  FLEXIBLE
# 208                                               AWEM  FULL_DAY
# 209                                          SberCloud  FULL_DAY
# 210                                   Reelmotion games  FULL_DAY
# 211                                          DATS.TEAM    REMOTE
# 212                                       СКБ Хроматэк  FULL_DAY
# 213                  Кадровое агентство Smart Business    REMOTE
# 214                                        Тагес Джамп  FULL_DAY
# 215                                          Marfatech  FULL_DAY
# 216                               DNS федеральный офис  FULL_DAY
# 217                               DNS федеральный офис  FULL_DAY
# 218                               DNS федеральный офис  FULL_DAY
# 219                               DNS федеральный офис  FULL_DAY
# 220                                   Waves Enterprise    REMOTE
# 221                  Центр образовательных услуг Білім  FULL_DAY
# 222                 Транспортный холдинг города Алматы  FLEXIBLE
# 223                                          Ехpress24  FULL_DAY
# 224                                           Noorsoft    REMOTE
# 225                                           Noorsoft  FULL_DAY
# 226                                        G-Core Labs  FULL_DAY
# 227                                        G-Core Labs  FULL_DAY
# 228                                        G-Core Labs  FULL_DAY
# 229                                        G-Core Labs  FULL_DAY
# 230                                        G-Core Labs  FULL_DAY
# 231                                        G-Core Labs  FULL_DAY
# 232                                         Bilim Land  FULL_DAY
# 233                                          АВИТО ТЕХ  FULL_DAY
# 234                             Группа Телематика-Один  FULL_DAY
# 235                                      Liepa Limited  FULL_DAY
# 236  Мобайл Телеком-Сервис (Объединенная Компания T...  FULL_DAY
# 237                                            GA Tech  FULL_DAY
# 238                                            GA Tech  FULL_DAY
# 239                                            GA Tech  FULL_DAY
# 240                                            GA Tech  FULL_DAY
# 241                                           Тинькофф  FULL_DAY
# 242                                           Тинькофф  FULL_DAY
# 243                                          Marfatech  FULL_DAY
# 244                                       Prime Source  FULL_DAY
# 245                                   Reelmotion games  FULL_DAY
# 246                                   Reelmotion games  FULL_DAY
# 247                                   Reelmotion games  FULL_DAY
# 248                  Кадровое агентство Smart Business    REMOTE
# 249                                            XIAG AG  FULL_DAY
# 250                                         Айти грэйд  FULL_DAY
# 251              BI.ZONE Направление Кибербезопасность  FULL_DAY
# 252                          NDM Systems Inc.,Компания  FULL_DAY
# 253                                       SpectrumData  FULL_DAY
# 254                                       SpectrumData  FULL_DAY
# 255                                       SpectrumData  FULL_DAY
# 256                                          Сима-ленд  FULL_DAY
# 257                                       Ozon Fintech  FLEXIBLE
# 258                                       Ozon Fintech  FLEXIBLE
# 259  Мобайл Телеком-Сервис (Объединенная Компания T...  FULL_DAY
# 260                                            АПРИКОД  FULL_DAY
# 261                                          АВИТО ТЕХ  FULL_DAY
# 262                                     Lilekov Studio    REMOTE
# 263                                        SoftGamings  FULL_DAY
# 264                                        SoftGamings  FULL_DAY
# 265                                        SoftGamings  FULL_DAY
# 266                                            сodenix  FULL_DAY
# 267                                           Тинькофф  FULL_DAY
# 268                                            Туту.ру  FULL_DAY
# 269                                                FIX    REMOTE
# 270                                            XIAG AG  FULL_DAY
# 271                                           Софтвайс  FULL_DAY
# 272                                            Туту.ру  FULL_DAY
# 273                                              AGIMA  FULL_DAY
# 274                                  Строительный Двор  FULL_DAY
# 275                                        Тагес Джамп    REMOTE
# 276                                         СолбегСофт  FULL_DAY
# 277                                       Boxberry: IT    REMOTE
# 278                                           Coins.ph    REMOTE
# 279                                  Accent Consulting  FLEXIBLE
# 280                                          SberCloud  FULL_DAY
# 281                                          SberCloud  FULL_DAY
# 282                                           SberTech  FLEXIBLE
# 283                                             Seldon    REMOTE
# 284                                             «МТС»   FULL_DAY
# 285           Центр анализа и расследования кибер атак  FULL_DAY
#
#      accept_temporary
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8                True
# 9               False
# 10              False
# 11              False
# 12              False
# 13              False
# 14               True
# 15              False
# 16              False
# 17              False
# 18              False
# 19              False
# 20              False
# 21              False
# 22              False
# 23              False
# 24              False
# 25               True
# 26              False
# 27              False
# 28              False
# 29              False
# 30              False
# 31              False
# 32              False
# 33              False
# 34              False
# 35              False
# 36              False
# 37              False
# 38              False
# 39              False
# 40              False
# 41               True
# 42              False
# 43              False
# 44              False
# 45              False
# 46              False
# 47              False
# 48              False
# 49              False
# 50              False
# 51              False
# 52              False
# 53              False
# 54              False
# 55              False
# 56              False
# 57               True
# 58              False
# 59              False
# 60              False
# 61              False
# 62              False
# 63              False
# 64              False
# 65              False
# 66              False
# 67              False
# 68              False
# 69              False
# 70              False
# 71              False
# 72              False
# 73              False
# 74               True
# 75              False
# 76              False
# 77              False
# 78               True
# 79              False
# 80              False
# 81              False
# 82              False
# 83              False
# 84              False
# 85               True
# 86               True
# 87               True
# 88              False
# 89              False
# 90              False
# 91              False
# 92              False
# 93              False
# 94              False
# 95              False
# 96              False
# 97              False
# 98              False
# 99              False
# 100             False
# 101             False
# 102             False
# 103             False
# 104             False
# 105             False
# 106              True
# 107             False
# 108             False
# 109             False
# 110             False
# 111              True
# 112             False
# 113             False
# 114              True
# 115             False
# 116             False
# 117             False
# 118              True
# 119             False
# 120             False
# 121             False
# 122             False
# 123             False
# 124             False
# 125             False
# 126             False
# 127             False
# 128             False
# 129             False
# 130             False
# 131             False
# 132             False
# 133             False
# 134             False
# 135             False
# 136             False
# 137             False
# 138             False
# 139             False
# 140             False
# 141             False
# 142             False
# 143             False
# 144             False
# 145             False
# 146             False
# 147             False
# 148             False
# 149             False
# 150             False
# 151             False
# 152             False
# 153             False
# 154             False
# 155             False
# 156             False
# 157             False
# 158             False
# 159             False
# 160             False
# 161             False
# 162             False
# 163             False
# 164             False
# 165             False
# 166             False
# 167             False
# 168             False
# 169             False
# 170             False
# 171             False
# 172             False
# 173             False
# 174             False
# 175             False
# 176             False
# 177             False
# 178             False
# 179             False
# 180             False
# 181             False
# 182              True
# 183             False
# 184             False
# 185              True
# 186             False
# 187             False
# 188             False
# 189             False
# 190             False
# 191             False
# 192             False
# 193             False
# 194             False
# 195             False
# 196             False
# 197             False
# 198             False
# 199             False
# 200             False
# 201             False
# 202             False
# 203             False
# 204             False
# 205              True
# 206             False
# 207             False
# 208             False
# 209             False
# 210             False
# 211             False
# 212             False
# 213             False
# 214             False
# 215             False
# 216             False
# 217             False
# 218             False
# 219             False
# 220             False
# 221              True
# 222             False
# 223             False
# 224             False
# 225             False
# 226             False
# 227             False
# 228             False
# 229             False
# 230             False
# 231             False
# 232             False
# 233             False
# 234              True
# 235             False
# 236             False
# 237             False
# 238             False
# 239             False
# 240             False
# 241             False
# 242             False
# 243             False
# 244             False
# 245             False
# 246             False
# 247             False
# 248             False
# 249             False
# 250             False
# 251             False
# 252             False
# 253             False
# 254             False
# 255             False
# 256             False
# 257             False
# 258             False
# 259             False
# 260             False
# 261             False
# 262              True
# 263             False
# 264             False
# 265             False
# 266             False
# 267             False
# 268             False
# 269             False
# 270             False
# 271             False
# 272             False
# 273             False
# 274             False
# 275             False
# 276             False
# 277             False
# 278             False
# 279             False
# 280             False
# 281             False
# 282             False
# 283             False
# 284             False
# 285             False

# %%
from collections import Counter
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

salary_series = pd.to_numeric(df["salary"], errors = "coerce")

print("search text:",vacancy_search_text)
print("Средняя зарплата: ",math.floor((salary_series.mean(skipna=True))))
print("Медианная зарплата: ",math.floor(salary_series.median(skipna=True)))
print("Среднеквадратичное отклонение зарплаты: ",math.floor(salary_series.std(skipna=True)))
vacancies_count = len(salary_series)
print("Вакансий: ",vacancies_count)
open_salary_vacancies = salary_series.count()
screwed_salary_vacancies = len(salary_series)-open_salary_vacancies
print("Вакансий с открытой зарплатой: ",
      open_salary_vacancies, "ед.,", 
      math.floor(100*open_salary_vacancies/vacancies_count), "%")
print("Вакансий без нижней или верхней границы зарплаты: ",
      screwed_salary_vacancies, "ед.,",  
      math.floor(100*screwed_salary_vacancies/vacancies_count), "%")

print("Вакансия с максимальной зарплатой")
pd.set_option("display.max_rows",None)
display(df[salary_series.idxmax():salary_series.idxmax()+1])
print("Вакансия с минимальной зарплатой")
pd.set_option("display.max_rows",None)
display(df[salary_series.idxmin():salary_series.idxmin()+1])


fz = plt.figure(figsize=(12, 7), dpi=100)
fz.add_subplot(2,1,1)
salary_series.hist()
plt.title('Salary')

fz.add_subplot(2,2,3)
plt.title('Schedule')
schedule_series = df["schedule"]
schedule_series = pd.Series(data=list(Counter(schedule_series.values)), 
                            index=list(Counter(schedule_series.values).values()))

patches, texts = plt.pie(schedule_series.index, labels = schedule_series.values)
plt.legend(patches, schedule_series.values)

fz.add_subplot(2,2,4)
plt.title('Accept_temporary')
accept_temporary_series = df["accept_temporary"]
accept_temporary_series = pd.Series(data=list(Counter(accept_temporary_series.values)), 
                            index=list(Counter(accept_temporary_series.values).values()))

patches, texts = plt.pie(accept_temporary_series.index, labels = accept_temporary_series.values)
plt.legend(patches, accept_temporary_series.values)
# Out:
# search text: golang middle
# Средняя зарплата:  207570
# Медианная зарплата:  188187
# Среднеквадратичное отклонение зарплаты:  98079
# Вакансий:  286
# Вакансий с открытой зарплатой:  138 ед., 48 %
# Вакансий без нижней или верхней границы зарплаты:  148 ед., 51 %
# Вакансия с максимальной зарплатой
#     Unnamed: 0                                         key_skills  \
# 61          61  Blockchain, Rust, DeFi, NEAR Protocol, DEX, Or...
#
#                                  name        id  \
# 61  Lead/Senior/Middle Rust Developer  50789953
#
#                                           description  salary  \
# 61  Algalon Capital is looking to hire a Lead/Seni...  604400
#
#                     creation_time         employer  schedule  accept_temporary
# 61  2022-01-04T10:01:05.352+03:00  Algalon Capital  FULL_DAY             False
# Вакансия с минимальной зарплатой
#      Unnamed: 0 key_skills         name        id  \
# 212         212        NaN  Программист  51952354
#
#                                            description salary  \
# 212  Наша команда занимается разработкой программн...  45000
#
#                      creation_time      employer  schedule  accept_temporary
# 212  2022-01-31T13:11:55.065+03:00  СКБ Хроматэк  FULL_DAY             False

# %%
from collections import Counter
import scipy
import re

def top_keys(df):
    # Collect keys from dataframe
    keys_df = df['key_skills'].tolist()
    # Create a list of keys for all vacancies
    lst_keys = []
    for keys_elem in keys_df:
        if type(keys_elem) == str:
            for el in keys_elem[0:].split(', '):
                if el != '':
                    lst_keys.append(re.sub('\'', '', el.lower()))

    # Unique keys and their counter
    set_keys = set(lst_keys)
    # Dict: {Key: Count}
    dct_keys = {el:lst_keys.count(el) for el in set_keys}
    # Sorted dict
    srt_keys = dict(sorted(dct_keys.items(), key=lambda x: x[1], reverse=True))
    # Return pandas series
    return pd.Series(srt_keys, name='key_skills')

# %%
def cut_frequencys (data_series, stat = "median"):
    #частоты частот
    freq = dict(Counter(list(data_series.values)))
    freq_values = list(freq.values())
    freq_values.sort(reverse=True)

    if stat == "mean":
        freq_border = scipy.mean(freq_values)
    else:
        freq_border = scipy.median(freq_values)

    new_series = data_series.copy()    
    for index, value in data_series.items():   
        if freq[value]>freq_border:
            new_series=new_series.drop(labels=index)
   
    return new_series

# %% [markdown]
# ### Key skills

# %%
from matplotlib import pyplot as plt

key_skills_freq_series = cut_frequencys (top_keys(df))

fz = plt.figure(figsize=(12, 8), dpi=100)
fz.add_subplot(1,1,1)
plt.xticks(rotation='vertical')
plt.barh(key_skills_freq_series.index, key_skills_freq_series.values)
# Out:
# <BarContainer object of 19 artists>

# %% [markdown]
# ### Key skills from description

# %%
descriptions = df.description

additional_tegs = []

for dsc in descriptions:
    searched = re.findall(r"(([A-z]+[\s/-]*)+)+", dsc)
    for pair in searched: 
        addteg = list(pair)[0]
        addteg = re.sub(r'\s+|\W+','', addteg)
        
        addteg = addteg.lower() 
        additional_tegs.append(addteg)
    

description_freq = pd.Series(Counter(additional_tegs)).sort_values(ascending=False)[:25]

                                            
fz = plt.figure(figsize=(12, 8), dpi=100)
fz.add_subplot(1,1,1)
plt.xticks(rotation='vertical')
plt.barh(description_freq.index, description_freq.values)
# Out:
# <BarContainer object of 25 artists>

# %%
! git add *
! git commit -m "some ambitious"
! git push
# Out:
# warning: LF will be replaced by CRLF in .ipynb_checkpoints/main-checkpoint.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in main.ipynb.
# The file will have its original line endings in your working directory
# [main d9dc791] some changes
#  5 files changed, 51481 insertions(+), 10161 deletions(-)
#  rewrite .ipynb_checkpoints/main-checkpoint.ipynb (70%)
#  create mode 100644 unity3d.csv
#  rewrite vacancy_cloud.png (95%)
#  create mode 100644 "\321\201++ middle.csv"
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/LuaSavage/hh_ru_parser.git
# To https://github.com/russianSlave/hh_ru_parser.git
#    fb3c89d..d9dc791  main -> main
